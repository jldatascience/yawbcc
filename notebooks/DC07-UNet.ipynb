# %% [markdown]
# # Segmentation avec U-Net
#
# Le résultat de la segmentation précédente par l'algorithme `watershed` est bon mais pas entièrement satisfaisant. Bien qu'une très grande majorité de leucocytes soit bien extrait des images, il y a quelques cas où la segmentation échoue notamment pour les cellules dont la surface est étendu et non convexe.
#
# Dans la technique précédente, les maximums locaux déterminent le nombre de cellules dans l'image et nous pouvons nous retrouver avec 2 minimums locaux pour la même cellule : il en résulte donc l'extraction de 2 cellules au lieu d'une seule.
#
# Nous allons utilisé le réseau U-Net pour réaliser cette segmentation donc dans un mode supervisé. Pour cela, nous devons disposer des images des cellules ainsi que d'un masque binaire représentant la zone d'intérêt (ROI) que nous voulons extraire. Le réseau va donc apprendre à repérer les ROI dans les images pour pouvoir les extraire plus tard par inférence.
#
# Cependant nous ne disposons pas de ces masques dans nos données et il serait fastidieux de les créer manuellement. Nous allons donc créer ces masques automatiquement. Dans la tentative précédente, nous avons généré ces masques mais comme ils ne sont pas satisfaisants pour toutes les cellules, nous ne pouvons pas leur faire confiance.

# %% [markdown]
# Nous commençons par vérifier que nous avons bien accès au GPU de la machine :

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

import tensorflow as tf
tf.config.experimental.list_physical_devices()
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'),
#  PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# Nous créons le modèle U-Net :
#
# ![U-Net](https://lmb.informatik.uni-freiburg.de/people/ronneber/u-net/u-net-architecture.png)

# %%
from keras.models import Model
from keras.layers import (Input, Conv2D, BatchNormalization, Activation,
                          MaxPool2D, Conv2DTranspose, Concatenate)

INPUT_SHAPE = (128, 128, 3)
BATCH_SIZE = 16


def conv_block(inp, num_filters):
    # Block 1
    x = Conv2D(num_filters, (3, 3), strides=1, padding='same')(inp)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    # Block 2
    x = Conv2D(num_filters, (3, 3), strides=1, padding='same')(x)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)

    return x


def encoder_block(inp, num_filters):
    x = conv_block(inp, num_filters)
    p = MaxPool2D((2, 2))(x)
    return x, p


def decoder_block(inp, enc, num_filters):
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding='same')(inp)
    x = Concatenate()([x, enc])
    x = conv_block(x, num_filters)
    return x


def create_model():
    # Input
    inputs = Input(INPUT_SHAPE)

    # Contraction part (top-down)
    e1, p1 = encoder_block(inputs, 64)
    e2, p2 = encoder_block(p1, 128)
    e3, p3 = encoder_block(p2, 256)
    e4, p4 = encoder_block(p3, 512)

    # Bottleneck
    b1 = conv_block(p4, 1024)

    # Expansion part (botom-up)
    d1 = decoder_block(b1, e4, 512)
    d2 = decoder_block(d1, e3, 256)
    d3 = decoder_block(d2, e2, 128)
    d4 = decoder_block(d3, e1, 64)

    # Output
    outputs = Conv2D(1, 1, padding="same", activation='sigmoid')(d4)

    model = Model(inputs, outputs, name="U-Net")
    return model


model = create_model()
model.summary()
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# Out:
# Model: "U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 128, 128, 64  1792        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 128, 128, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 128, 128, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 128, 128, 64  36928       ['activation[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 128, 128, 64  256        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  activation_1 (Activation)      (None, 128, 128, 64  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 64, 64, 64)   0           ['activation_1[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 64, 64, 128)  73856       ['max_pooling2d[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 64, 64, 128)  512        ['conv2d_2[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 64, 64, 128)  0           ['batch_normalization_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 64, 64, 128)  147584      ['activation_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 64, 64, 128)  512        ['conv2d_3[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 64, 64, 128)  0           ['batch_normalization_3[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 128)  0          ['activation_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 32, 32, 256)  295168      ['max_pooling2d_1[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 32, 32, 256)  1024       ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 32, 32, 256)  0           ['batch_normalization_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 32, 32, 256)  590080      ['activation_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 32, 32, 256)  1024       ['conv2d_5[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 32, 32, 256)  0           ['batch_normalization_5[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 256)  0          ['activation_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 16, 16, 512)  1180160     ['max_pooling2d_2[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 16, 16, 512)  2048       ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_6 (Activation)      (None, 16, 16, 512)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 16, 16, 512)  2359808     ['activation_6[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 16, 16, 512)  2048       ['conv2d_7[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 16, 16, 512)  0           ['batch_normalization_7[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 512)   0           ['activation_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 8, 8, 1024)   4719616     ['max_pooling2d_3[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 8, 8, 1024)  4096        ['conv2d_8[0][0]']
#  rmalization)
#
#  activation_8 (Activation)      (None, 8, 8, 1024)   0           ['batch_normalization_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 8, 8, 1024)   9438208     ['activation_8[0][0]']
#  batch_normalization_9 (BatchNo  (None, 8, 8, 1024)  4096        ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_9 (Activation)      (None, 8, 8, 1024)   0           ['batch_normalization_9[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 16, 16, 512)  2097664    ['activation_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 16, 16, 1024  0           ['conv2d_transpose[0][0]',
#                                 )                                 'activation_7[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 16, 16, 512)  4719104     ['concatenate[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 16, 16, 512)  2048       ['conv2d_10[0][0]']
#  ormalization)
#
#  activation_10 (Activation)     (None, 16, 16, 512)  0           ['batch_normalization_10[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 16, 16, 512)  2359808     ['activation_10[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 16, 16, 512)  2048       ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 16, 16, 512)  0           ['batch_normalization_11[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 32, 32, 256)  524544     ['activation_11[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 32, 32, 512)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'activation_5[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 32, 32, 256)  1179904     ['concatenate_1[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_12[0][0]']
#  ormalization)
#
#  activation_12 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_12[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 32, 32, 256)  590080      ['activation_12[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_13[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 64, 64, 128)  131200     ['activation_13[0][0]']
#  spose)
#
#  concatenate_2 (Concatenate)    (None, 64, 64, 256)  0           ['conv2d_transpose_2[0][0]',
#                                                                   'activation_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 64, 64, 128)  295040      ['concatenate_2[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 64, 64, 128)  512        ['conv2d_14[0][0]']
#  ormalization)
#
#  activation_14 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_14[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 64, 64, 128)  147584      ['activation_14[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 64, 64, 128)  512        ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_15[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 128, 128, 64  32832      ['activation_15[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 128, 128, 12  0           ['conv2d_transpose_3[0][0]',
#                                 8)                                'activation_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 128, 128, 64  73792       ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_16 (BatchN  (None, 128, 128, 64  256        ['conv2d_16[0][0]']
#  ormalization)                  )
#
#  activation_16 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_16[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 128, 128, 64  36928       ['activation_16[0][0]']
#                                 )
#  batch_normalization_17 (BatchN  (None, 128, 128, 64  256        ['conv2d_17[0][0]']
#  ormalization)                  )
#
#  activation_17 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_17[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 128, 128, 1)  65          ['activation_17[0][0]']
#
# ==================================================================================================
# Total params: 31,055,297
# Trainable params: 31,043,521
# Non-trainable params: 11,776
# __________________________________________________________________________________________________

# %% [markdown]
# Nous avons isolé 1600 images et masques de la segmentation à base de couleur. Sur ces 1600 images, nous avons rejeté 259 et conservé 1341 images. Nous créons nos jeux d'entraînement, de test et de validation.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pathlib
import cv2
from sklearn.model_selection import train_test_split

DATA_DIR = pathlib.Path('/home/damien/yawbcc_data/barcelona_256_unet')

image_directory = DATA_DIR / 'images'
mask_directory = DATA_DIR / 'masks'

# Load datasets
image_dataset = pd.Series(sorted([filename for filename in image_directory.glob('*.jpg')]))
mask_dataset = pd.Series(sorted([filename for filename in mask_directory.glob('*.npy')]))

# Split datasets
X_train, X_test, y_train, y_test = train_test_split(image_dataset, mask_dataset, test_size=0.2, random_state=2022)
X_train, X_valid, y_train, y_valid = train_test_split(X_train, y_train, test_size=0.2, random_state=2022)

# %% [markdown]
# Nous créons une classe pour générer les batchs d'images (X) et de masques (y)

# %%
class WBCDataSequence(tf.keras.utils.Sequence):

    def __init__(self, image_set, mask_set, batch_size=32, image_size=(128, 128)):
        self.image_set = np.array(image_set)
        self.mask_set = np.array(mask_set)
        self.batch_size = batch_size
        self.image_size = image_size

    def __get_input(self, path):
        image = tf.keras.preprocessing.image.load_img(path, color_mode='rgb')
        image_arr = tf.keras.preprocessing.image.img_to_array(image)
        image_arr = cv2.cvtColor(image_arr, cv2.COLOR_RGB2XYZ)
        image_arr = tf.image.resize(image_arr, self.image_size).numpy()
        return image_arr / 255.

    def __get_output(self, path):
        mask_arr = (cv2.resize(np.load(path), self.image_size) > 0).astype(np.uint8)
        return mask_arr

    def __get_data(self, images, masks):
        image_batch = images
        mask_batch = masks
        image_batch = np.asarray([self.__get_input(path) for path in image_batch])
        mask_batch = np.asarray([self.__get_output(path) for path in mask_batch])
        return image_batch, mask_batch

    def __getitem__(self, index):
        images = self.image_set[index * self.batch_size:(index + 1) * self.batch_size]
        masks = self.mask_set[index * self.batch_size:(index + 1) * self.batch_size]
        images, masks = self.__get_data(images, masks)        
        return images, masks

    def __len__(self):
        return len(self.image_set) // self.batch_size + (len(self.image_set) % self.batch_size > 0)


train_ds = WBCDataSequence(X_train, y_train, image_size=INPUT_SHAPE[:2], batch_size=BATCH_SIZE)
valid_ds = WBCDataSequence(X_valid, y_valid, image_size=INPUT_SHAPE[:2], batch_size=BATCH_SIZE)
test_ds = WBCDataSequence(X_test, y_test, image_size=INPUT_SHAPE[:2], batch_size=BATCH_SIZE)

# %% [markdown]
# ### Entraînement du modèle

# %%
history = model.fit(train_ds,
                    batch_size=BATCH_SIZE,
                    epochs=25,
                    validation_data=valid_ds,
                    shuffle=False)

model.evaluate(test_ds)
model.save(DATA_DIR / 'unet_128_5.hdf5')

# %%
from keras.models import load_model
model = load_model(DATA_DIR / 'unet_128_5.hdf5', compile=True)
model.evaluate(test_ds)
# Out:
# 17/17 [==============================] - 9s 297ms/step - loss: 0.0086 - accuracy: 0.9972
# [0.008620369248092175, 0.9972246289253235]

# %% [markdown]
# ### Interprétation des résultats

# %%
import itertools

preds = model.predict(test_ds)
batches = list(zip(*test_ds))
images = list(itertools.chain(*batches[0]))
masks = list(itertools.chain(*batches[1]))
# Out:
# 17/17 [==============================] - 3s 159ms/step

# %%
pd.DataFrame({'X': [p.name for p in X_test],
              'y': [p.name for p in y_test]})
# Out:
#                        X                    y
# 0         BNE_727973.jpg       BNE_727973.npy
# 1          MO_993578.jpg        MO_993578.npy
# 2         MMY_873744.jpg       MMY_873744.npy
# 3          MO_902264.jpg        MO_902264.npy
# 4    PLATELET_530681.jpg  PLATELET_530681.npy
# ..                   ...                  ...
# 264       BNE_355910.jpg       BNE_355910.npy
# 265       BNE_344758.jpg       BNE_344758.npy
# 266  PLATELET_885144.jpg  PLATELET_885144.npy
# 267        EO_766383.jpg        EO_766383.npy
# 268         BA_89223.jpg         BA_89223.npy
#
# [269 rows x 2 columns]

# %%
from tqdm.auto import tqdm
from sklearn.metrics import accuracy_score, precision_score, recall_score

THRESH = 0.5
metrics = []

for idx, path in enumerate(tqdm(X_test)):

    # Convert to integer images
    X = np.round(255 * images[idx]).astype(np.uint8)
    y = 255 * (masks[idx] >= THRESH).astype(np.uint8)
    p = 255 * (preds[idx].squeeze() >= THRESH).astype(np.uint8)

    # Postprocess mask
    contours, _ = cv2.findContours(p, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
    p = cv2.drawContours(np.zeros(p.shape, np.uint8), contours, 0, 255, cv2.FILLED)

    # Metrics
    accuracy = accuracy_score(y.ravel(), p.ravel())  # real results / total
    precision = precision_score(y.ravel(), p.ravel(), pos_label=255)  # true positive / actual results (red)
    recall = recall_score(y.ravel(), p.ravel(), pos_label=255)  # true positive / predicted results (green)
    metrics.append([path.stem, str(path), accuracy, precision, recall])

    # Display figure
    fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(12, 4))

    ax1.set_title(f'WBC: {path.stem}')
    ax1.imshow(X[..., 1], cmap='gray')
    ax1.axis('off')

    ax2.set_title('Actual mask')
    ax2.imshow(y, cmap='gray')
    ax2.axis('off')

    ax3.set_title('Predicted mask')
    ax3.imshow(p, cmap='gray')
    ax3.axis('off')

    ax3.scatter(*np.flip(np.where(y < p)), c='g', s=1, marker='s')  # False positive (Type I)
    ax3.scatter(*np.flip(np.where(y > p)), c='r', s=1, marker='s')  # False negative (Type II)

    plt.tight_layout()
    plt.savefig(DATA_DIR / 'output' / f'{idx:03}_{path.stem}.png')
    plt.close()

metrics = pd.DataFrame(metrics, columns=['name', 'path', 'accuracy', 'precision', 'recall'])
metrics.head()
# Out:
#   0%|          | 0/269 [00:00<?, ?it/s]
#               name                                               path  \
# 0       BNE_727973  /home/damien/yawbcc_data/barcelona_256_unet/im...
# 1        MO_993578  /home/damien/yawbcc_data/barcelona_256_unet/im...
# 2       MMY_873744  /home/damien/yawbcc_data/barcelona_256_unet/im...
# 3        MO_902264  /home/damien/yawbcc_data/barcelona_256_unet/im...
# 4  PLATELET_530681  /home/damien/yawbcc_data/barcelona_256_unet/im...
#
#    accuracy  precision    recall
# 0  0.997925   1.000000  0.991260
# 1  0.998718   0.999761  0.995238
# 2  0.998779   1.000000  0.993213
# 3  0.998840   0.999508  0.995829
# 4  0.999390   1.000000  0.986413

# %%
metrics['f1-score'] = 2 * (metrics['precision'] * metrics['recall']) / (metrics['precision'] + metrics['recall'])
metrics.sort_values('f1-score', na_position='first').head(30)
# Out:
#                 name                                               path  \
# 27         BA_882416  /home/damien/yawbcc_data/barcelona_256_unet/im...
# 40         LY_153467  /home/damien/yawbcc_data/barcelona_256_unet/im...
# 47         EO_284748  /home/damien/yawbcc_data/barcelona_256_unet/im...
# 69         BA_700831  /home/damien/yawbcc_data/barcelona_256_unet/im...
# 106         MY_91439  /home/damien/yawbcc_data/barcelona_256_unet/im...
# 162        BA_338836  /home/damien/yawbcc_data/barcelona_256_unet/im...
# 182       BNE_218516  /home/damien/yawbcc_data/barcelona_256_unet/im...
# 205        BA_846077  /home/damien/yawbcc_data/barcelona_256_unet/im...
# 261       ERB_878703  /home/damien/yawbcc_data/barcelona_256_unet/im...
# 150        EO_321528  /home/damien/yawbcc_data/barcelona_256_unet/im...
# 96   PLATELET_146840  /home/damien/yawbcc_data/barcelona_256_unet/im...
# 181  PLATELET_592947  /home/damien/yawbcc_data/barcelona_256_unet/im...
# 66   PLATELET_328388  /home/damien/yawbcc_data/barcelona_256_unet/im...
# 92           ERB_685  /home/damien/yawbcc_data/barcelona_256_unet/im...
# 175        MO_832241  /home/damien/yawbcc_data/barcelona_256_unet/im...
# 13        SNE_543039  /home/damien/yawbcc_data/barcelona_256_unet/im...
# 158        MO_170993  /home/damien/yawbcc_data/barcelona_256_unet/im...
# 196  PLATELET_837118  /home/damien/yawbcc_data/barcelona_256_unet/im...
# 247        MY_894949  /home/damien/yawbcc_data/barcelona_256_unet/im...
# 93        SNE_271109  /home/damien/yawbcc_data/barcelona_256_unet/im...
# 54         MO_258162  /home/damien/yawbcc_data/barcelona_256_unet/im...
# 131        BA_382161  /home/damien/yawbcc_data/barcelona_256_unet/im...
# 86         MO_115081  /home/damien/yawbcc_data/barcelona_256_unet/im...
# 72          MY_98273  /home/damien/yawbcc_data/barcelona_256_unet/im...
# 268         BA_89223  /home/damien/yawbcc_data/barcelona_256_unet/im...
# 125        BA_992459  /home/damien/yawbcc_data/barcelona_256_unet/im...
# 232         BA_84276  /home/damien/yawbcc_data/barcelona_256_unet/im...
# 138  PLATELET_503986  /home/damien/yawbcc_data/barcelona_256_unet/im...
# 173         LY_32573  /home/damien/yawbcc_data/barcelona_256_unet/im...
# 178        MMY_63566  /home/damien/yawbcc_data/barcelona_256_unet/im...
#
#      accuracy  precision    recall  f1-score
# 27   0.798157   0.000000  0.000000       NaN
# 40   0.885010   0.000000  0.000000       NaN
# 47   0.649658   0.000000  0.000000       NaN
# 69   0.829956   0.000000  0.000000       NaN
# 106  0.817505   0.000000  0.000000       NaN
# 162  0.797913   0.000000  0.000000       NaN
# 182  0.798035   0.000000  0.000000       NaN
# 205  0.810913   0.000000  0.000000       NaN
# 261  0.870605   0.000000  0.000000       NaN
# 150  0.662720   1.000000  0.000181  0.000362
# 96   0.960144   1.000000  0.073759  0.137384
# 181  0.979065   1.000000  0.388592  0.559692
# 66   0.989441   1.000000  0.731366  0.844843
# 92   0.981445   1.000000  0.799868  0.888808
# 175  0.968323   1.000000  0.916800  0.956594
# 13   0.980591   0.993177  0.947378  0.969737
# 158  0.980652   1.000000  0.945803  0.972147
# 196  0.997864   1.000000  0.945820  0.972156
# 247  0.989441   0.973644  0.973939  0.973792
# 93   0.986816   0.995788  0.952821  0.973831
# 54   0.983276   0.998949  0.955109  0.976537
# 131  0.989563   0.959398  0.994426  0.976598
# 86   0.986023   0.996996  0.961434  0.978892
# 72   0.990601   0.996379  0.964930  0.980402
# 268  0.992554   0.995654  0.967421  0.981334
# 125  0.993774   0.968674  0.995707  0.982004
# 232  0.991150   0.997056  0.968311  0.982473
# 138  0.998596   1.000000  0.966276  0.982849
# 173  0.996521   0.974133  0.992216  0.983091
# 178  0.991455   0.984655  0.982336  0.983494

# %%
from yawbcc.datasets import load_barcelona_wbc

meta = load_barcelona_wbc()
image_list = [path.name for path in image_dataset]
df = meta[meta['image'].isin(image_list)]
df.head()
# Out:
#             image     group label  width  height  \
# 6   MO_526259.jpg  MONOCYTE    MO    360     363
# 22  MO_134596.jpg  MONOCYTE    MO    360     363
# 42  MO_688574.jpg  MONOCYTE    MO    360     363
# 45   MO_61107.jpg  MONOCYTE    MO    360     363
# 57  MO_578103.jpg  MONOCYTE    MO    360     363
#
#                                                  path
# 6   /home/damien/yawbcc_data/barcelona/monocyte/MO...
# 22  /home/damien/yawbcc_data/barcelona/monocyte/MO...
# 42  /home/damien/yawbcc_data/barcelona/monocyte/MO...
# 45  /home/damien/yawbcc_data/barcelona/monocyte/MO...
# 57  /home/damien/yawbcc_data/barcelona/monocyte/MO...

# %% [markdown]
# ### Test
#
# Nous pouvons également testé avec les images que nous avons rejetées manuellement pour l'entrainement du réseau U-Net suite à la segmentation basée sur la vision par ordinateur. Nous pourrons ainsi vérifier si U-Net fait mieux que la méthode colorimétrique.

# %%
image_directory2 = DATA_DIR / 'trash' / 'images'
mask_directory2 = DATA_DIR / 'trash' / 'masks'

X_test2 = sorted([filename for filename in image_directory2.glob('*.jpg')])
y_test2 = sorted([filename for filename in mask_directory2.glob('*.npy')])

test_ds2 = WBCDataSequence(X_test2, y_test2, image_size=INPUT_SHAPE[:2], batch_size=BATCH_SIZE)
model.evaluate(test_ds2)
# Out:
# 17/17 [==============================] - 4s 249ms/step - loss: 0.3875 - accuracy: 0.9225
# [0.38747674226760864, 0.922502338886261]

# %%
from tqdm.auto import tqdm
from sklearn.metrics import accuracy_score, precision_score, recall_score

THRESH = 0.2
metrics = []

preds = model.predict(test_ds2)
batches = list(zip(*test_ds2))
images = list(itertools.chain(*batches[0]))
masks = list(itertools.chain(*batches[1]))

for idx, path in enumerate(tqdm(X_test2)):

    # Convert to integer images
    X = np.round(255 * images[idx]).astype(np.uint8)
    y = 255 * (masks[idx] >= THRESH).astype(np.uint8)
    p = 255 * (preds[idx].squeeze() >= THRESH).astype(np.uint8)

    # Postprocess mask
    #contours, _ = cv2.findContours(p, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
    #p = cv2.drawContours(np.zeros(p.shape, np.uint8), contours, 0, 255, cv2.FILLED)

    # Metrics
    accuracy = accuracy_score(y.ravel(), p.ravel())  # real results / total
    precision = precision_score(y.ravel(), p.ravel(), pos_label=255)  # true positive / actual results (red)
    recall = recall_score(y.ravel(), p.ravel(), pos_label=255)  # true positive / predicted results (green)
    metrics.append([path.stem, accuracy, precision, recall])

    # Display figure
    fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(12, 4))

    ax1.set_title(f'WBC: {path.stem}')
    ax1.imshow(X[..., 1], cmap='gray')
    ax1.axis('off')

    ax2.set_title('Actual mask')
    ax2.imshow(y, cmap='gray')
    ax2.axis('off')

    ax3.set_title('Predicted mask')
    ax3.imshow(p, cmap='gray')
    ax3.axis('off')

    ax3.scatter(*np.flip(np.where(y < p)), c='g', s=1, marker='s')  # False positive (Type I)
    ax3.scatter(*np.flip(np.where(y > p)), c='r', s=1, marker='s')  # False negative (Type II)

    plt.tight_layout()
    plt.savefig(DATA_DIR / 'trash' / 'output' / f'{idx:03}_{path.stem}.png')
    plt.close()

metrics = pd.DataFrame(metrics, columns=['name', 'accuracy', 'precision', 'recall'])
metrics.head()
# Out:
# 17/17 [==============================] - 3s 159ms/step
#   0%|          | 0/259 [00:00<?, ?it/s]
# /home/damien/devel/datascientest/venv/lib/python3.9/site-packages/sklearn/metrics/_classification.py:1334: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#         name  accuracy  precision    recall
# 0  BA_114542  0.998230   0.998619  0.991432
# 1  BA_172469  0.921997   0.906972  0.839854
# 2  BA_202924  0.961548   0.861731  0.997419
# 3  BA_243213  0.991699   0.974398  0.990630
# 4  BA_267693  0.947510   0.991311  0.824442
